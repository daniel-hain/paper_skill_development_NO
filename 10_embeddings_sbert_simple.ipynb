# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-hain/paper_skill_development_NO/blob/main/10_embeddings_sbert_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing dependencies needed for this notebook

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install -qU transformers sentence-transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 102.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 55.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.2/224.2 kB 27.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.2 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer, util

# %%
import pickle
import pandas as pd
import numpy as np

# %% [markdown]
# ---
#
# ## Using sentence-transformers

# %%
model = SentenceTransformer('NbAiLab/nb-sbert-base')

# %% [markdown]
# # Embeddings Skills

# %%
# Read the CSV file
df_jobs = pd.read_csv("/content/gdrive/MyDrive/00_projects/project_2023_skills_NO/text_skills_plain.csv")

# %%
list_skills = df_skills['text']
list_skills = list_skills.tolist()

# %%
skills_embeddings = model.encode(list_skills, show_progress_bar=True, convert_to_tensor=True)
# Out:
# Batches:   0%|          | 0/435 [00:00<?, ?it/s]

# %%
# Save as pickle (alternative)
with open(f"{embeddings_dir}/skills_embeddings.pickle", 'wb') as pkl:
    pickle.dump(skills_embeddings, pkl)

#with open(f"{embeddings_dir}/skills_embeddings.pickle", 'rb') as pkl:
 #   doc_embedding = pickle.load(pkl)

# %% [markdown]
# # Embedding jobs

# %%
# Read the CSV file
list_jobs  = pd.read_csv("/content/gdrive/MyDrive/00_projects/project_2023_skills_NO/text_job_plain.csv")['text'].tolist()

# %%
jobs_embeddings = model.encode(list_jobs, show_progress_bar=True, convert_to_tensor=True)
# Out:
# Batches:   0%|          | 0/1012808 [00:00<?, ?it/s]

# %%
# Save
with open(f"{embeddings_dir}/job_embeddings.pickle", 'wb') as pkl:
    pickle.dump(jobs_embeddings, pkl)

#with open('skill_embedding.pickle', 'rb') as pkl:
 #   doc_embedding = pickle.load(pkl)
